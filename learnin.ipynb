# %%
# !git add .
# !git commit -m 'learned basics in databricks'
# !git push

# %%
# %sql
create catalog demo_catalog

# %%
# %sql
drop catalog demo_catalog cascade

# %%
# %sql
create catalog demo_catalog

# %%
# %sql
create schema demo_catalog.demo_schema

# %%
# %sql
create table demo_catalog.demo_schema.demo_table(
    id int,
    name varchar(50)
)using delta;

# %%
# %sql
select * from demo_catalog.demo_schema.demo_table;

# %%
# %sql
insert into demo_catalog.demo_schema.demo_table values(1, 'Abishek');

# %%
# %sql
select * from demo_catalog.demo_schema.demo_table;

# %%
# %sql
drop table demo_catalog.demo_schema.demo_table;

# %%
# %sql
create volume demo_catalog.demo_schema.demo_volume;

# %%
# %sql
-- database and schema is same
create database demo_catalog.demo_database;
